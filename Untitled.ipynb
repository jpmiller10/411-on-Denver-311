# %%
import numpy as np
import pandas as pd
import datetime
import geopandas
import json
import os
import folium
from folium.plugins import HeatMap

# %%
df = pd.read_pickle('data/geo_requests_2018_pickled_df')

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 156739 entries, 0 to 459626
# Data columns (total 10 columns):
# Case Summary         156401 non-null object
# Case Created dttm    156739 non-null datetime64[ns]
# Case Closed dttm     143750 non-null datetime64[ns]
# Longitude            156739 non-null float64
# Latitude             156739 non-null float64
# Agency               156735 non-null category
# Response Time        143750 non-null timedelta64[ns]
# geometry             156739 non-null geometry
# index_right          156739 non-null int64
# NBHD_NAME            156739 non-null object
# dtypes: category(1), datetime64[ns](2), float64(2), geometry(1), int64(1), object(2), timedelta64[ns](1)
# memory usage: 12.1+ MB

# %%
df = df.rename(columns = {'Case Summary': 'Case_Summary', 'Case Created dttm': 'Case_Created_dttm', 
                          'Case Closed dttm': 'Case_Closed_dttm', 'Response Time': 'Response_Time'})

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 156739 entries, 0 to 459626
# Data columns (total 10 columns):
# Case_Summary         156401 non-null object
# Case_Created_dttm    156739 non-null datetime64[ns]
# Case_Closed_dttm     143750 non-null datetime64[ns]
# Longitude            156739 non-null float64
# Latitude             156739 non-null float64
# Agency               156735 non-null category
# Response_Time        143750 non-null timedelta64[ns]
# geometry             156739 non-null geometry
# index_right          156739 non-null int64
# NBHD_NAME            156739 non-null object
# dtypes: category(1), datetime64[ns](2), float64(2), geometry(1), int64(1), object(2), timedelta64[ns](1)
# memory usage: 12.1+ MB

# %%
denver_map = folium.Map(location=[39.75782,-104.831338],
                        zoom_start=11,
                        tiles="Stamen Toner")

# %%
denver_map

# %%
def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.Latitude, point.Longitude],
                        radius=2,
                        weight=0,#remove outline
                        popup = str('Case Summary: ' + str(point.Case_Summary) \
                                        + '\nAgency: ' + str(point.Agency) \
                                        + '\nCase Opened: ' + str(point.Case_Created_dttm) \
                                        + '\nResponse Time: '+ str(point.Response_Time) 
                                        ),
                        fill_color='#222222').add_to(denver_map)

# %%
df_counters['Name'][point])

# %%
df['Agency'].values

# %%
gb_pub = df.groupby('Agency').get_group('Public Works')
gb_pub.info()

# %%
gb_ea1 = df.groupby('Agency').get_group('External Agency')
gb_ea1.info()

# %%
gb_311 = df.groupby('Agency').get_group('311')
gb_311.info()

# %%
gb_cc = df.groupby('Agency').get_group('City Council')
gb_cc.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 47 entries, 168234 to 459829
# Data columns (total 10 columns):
# Case_Summary         47 non-null object
# Case_Created_dttm    47 non-null datetime64[ns]
# Case_Closed_dttm     39 non-null datetime64[ns]
# Longitude            47 non-null float64
# Latitude             47 non-null float64
# Agency               47 non-null category
# Response_Time        39 non-null timedelta64[ns]
# geometry             47 non-null geometry
# index_right          47 non-null int64
# NBHD_NAME            47 non-null object
# dtypes: category(1), datetime64[ns](2), float64(2), geometry(1), int64(1), object(2), timedelta64[ns](1)
# memory usage: 4.5+ KB

# %%
gb_cc.apply(plotDot, axis = 1)
denver_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
